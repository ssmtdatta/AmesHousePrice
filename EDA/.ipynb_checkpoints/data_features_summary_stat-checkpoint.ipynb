# %% [markdown]
# ### Notebook Summary

# %% [markdown]
# * Read csv data as Pandas dataframe
# * Get numeric column names
# * Consider the numeric columns that are measurements
# * Obtain a statistical summary of the numeric columns
#     - mean
#     - median
#     - standard deviation
#     - skewness
#     - kurtosis
#     - zscore

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from scipy.stats.mstats import zscore

# %% [markdown]
# ### Directory

# %%
BASE_DIR = "../AmesHousing/"
DATA_IN = BASE_DIR+"DataDwn/"

# %% [markdown]
# ### Training Data

# %%
trn = pd.read_csv(DATA_IN+"train.csv")
trn.shape
# Out:
# (1460, 81)

# %% [markdown]
# **Numeric column names**

# %%
trn_num = trn._get_numeric_data()
trn_num.columns.values
# Out:
# array(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'], dtype=object)

# %% [markdown]
# **Feature names that (aparently) indicate measurements**

# %%
feature_names = ['LotFrontage', 'LotArea', 'MasVnrArea',
       'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 
       '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 
       'BsmtFullBath','BsmtHalfBath', 'FullBath', 'HalfBath', 
       'BedroomAbvGr','KitchenAbvGr', 'TotRmsAbvGrd', 
       'Fireplaces',
       'GarageCars', 'GarageArea', 
       'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 
       'SalePrice']
print(len(feature_names), "features selected")
# Out:
# 28 features selected

# %% [markdown]
# ### Statistical summary

# %%
trn_num = trn._get_numeric_data()
trn_num.shape
# Out:
# (1460, 38)

# %%
for feature in feature_names:
    print(feature)
    print(trn_num[feature].describe())
    skewness = trn_num[feature].skew()
    kurtosis = trn_num[feature].kurt()
    feature_dropna = trn_num[feature].dropna(axis=0, how='any')
    f = feature_dropna.tolist()
    z = zscore(f)
    outliers = len(np.where(z >= 3)[0]) + len(np.where(z <= -3)[0])
    
    print("Mean: ",  np.mean(f))
    print("Median: ",  np.median(f))
    print("Skewness:", skewness)
    print("Kurtosis:", kurtosis)
    print("Outliers:", outliers)
    print(" ")
# Out:
# LotFrontage
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64
# Mean:  70.049958368
# Median:  69.0
# Skewness: 2.16356914232
# Kurtosis: 17.4528672598
# Outliers: 12
#
# LotArea
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64
# Mean:  10516.8280822
# Median:  9478.5
# Skewness: 12.2076878512
# Kurtosis: 203.243271019
# Outliers: 13
#
# MasVnrArea
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64
# Mean:  103.685261708
# Median:  0.0
# Skewness: 2.66908421018
# Kurtosis: 10.0824173174
# Outliers: 32
#
# BsmtFinSF1
# count    1460.000000
# mean      443.639726
# std       456.098091
# min         0.000000
# 25%         0.000000
# 50%       383.500000
# 75%       712.250000
# max      5644.000000
# Name: BsmtFinSF1, dtype: float64
# Mean:  443.639726027
# Median:  383.5
# Skewness: 1.68550307191
# Kurtosis: 11.118236292
# Outliers: 6
#
# BsmtFinSF2
# count    1460.000000
# mean       46.549315
# std       161.319273
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1474.000000
# Name: BsmtFinSF2, dtype: float64
# Mean:  46.5493150685
# Median:  0.0
# Skewness: 4.25526110893
# Kurtosis: 20.1133375456
# Outliers: 50
#
# BsmtUnfSF
# count    1460.000000
# mean      567.240411
# std       441.866955
# min         0.000000
# 25%       223.000000
# 50%       477.500000
# 75%       808.000000
# max      2336.000000
# Name: BsmtUnfSF, dtype: float64
# Mean:  567.240410959
# Median:  477.5
# Skewness: 0.920268452804
# Kurtosis: 0.474993987809
# Outliers: 11
#
# TotalBsmtSF
# count    1460.000000
# mean     1057.429452
# std       438.705324
# min         0.000000
# 25%       795.750000
# 50%       991.500000
# 75%      1298.250000
# max      6110.000000
# Name: TotalBsmtSF, dtype: float64
# Mean:  1057.42945205
# Median:  991.5
# Skewness: 1.52425454906
# Kurtosis: 13.250483282
# Outliers: 10
#
# 1stFlrSF
# count    1460.000000
# mean     1162.626712
# std       386.587738
# min       334.000000
# 25%       882.000000
# 50%      1087.000000
# 75%      1391.250000
# max      4692.000000
# Name: 1stFlrSF, dtype: float64
# Mean:  1162.62671233
# Median:  1087.0
# Skewness: 1.37675662203
# Kurtosis: 5.74584148244
# Outliers: 12
#
# 2ndFlrSF
# count    1460.000000
# mean      346.992466
# std       436.528436
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       728.000000
# max      2065.000000
# Name: 2ndFlrSF, dtype: float64
# Mean:  346.992465753
# Median:  0.0
# Skewness: 0.813029816302
# Kurtosis: -0.553463557608
# Outliers: 4
#
# LowQualFinSF
# count    1460.000000
# mean        5.844521
# std        48.623081
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       572.000000
# Name: LowQualFinSF, dtype: float64
# Mean:  5.84452054795
# Median:  0.0
# Skewness: 9.01134128847
# Kurtosis: 83.2348166744
# Outliers: 20
#
# GrLivArea
# count    1460.000000
# mean     1515.463699
# std       525.480383
# min       334.000000
# 25%      1129.500000
# 50%      1464.000000
# 75%      1776.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64
# Mean:  1515.46369863
# Median:  1464.0
# Skewness: 1.36656035602
# Kurtosis: 4.89512058069
# Outliers: 16
#
# BsmtFullBath
# count    1460.000000
# mean        0.425342
# std         0.518911
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: BsmtFullBath, dtype: float64
# Mean:  0.425342465753
# Median:  0.0
# Skewness: 0.596066609663
# Kurtosis: -0.839098265463
# Outliers: 16
#
# BsmtHalfBath
# count    1460.000000
# mean        0.057534
# std         0.238753
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         2.000000
# Name: BsmtHalfBath, dtype: float64
# Mean:  0.0575342465753
# Median:  0.0
# Skewness: 4.10340269796
# Kurtosis: 16.3966419454
# Outliers: 82
#
# FullBath
# count    1460.000000
# mean        1.565068
# std         0.550916
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         3.000000
# Name: FullBath, dtype: float64
# Mean:  1.56506849315
# Median:  2.0
# Skewness: 0.0365615584027
# Kurtosis: -0.857042821274
# Outliers: 0
#
# HalfBath
# count    1460.000000
# mean        0.382877
# std         0.502885
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         2.000000
# Name: HalfBath, dtype: float64
# Mean:  0.382876712329
# Median:  0.0
# Skewness: 0.675897448234
# Kurtosis: -1.07692728415
# Outliers: 12
#
# BedroomAbvGr
# count    1460.000000
# mean        2.866438
# std         0.815778
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         8.000000
# Name: BedroomAbvGr, dtype: float64
# Mean:  2.86643835616
# Median:  3.0
# Skewness: 0.211790096275
# Kurtosis: 2.23087458219
# Outliers: 14
#
# KitchenAbvGr
# count    1460.000000
# mean        1.046575
# std         0.220338
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: KitchenAbvGr, dtype: float64
# Mean:  1.04657534247
# Median:  1.0
# Skewness: 4.48839677707
# Kurtosis: 21.5324038401
# Outliers: 68
#
# TotRmsAbvGrd
# count    1460.000000
# mean        6.517808
# std         1.625393
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        14.000000
# Name: TotRmsAbvGrd, dtype: float64
# Mean:  6.51780821918
# Median:  6.0
# Skewness: 0.676340836436
# Kurtosis: 0.880761565719
# Outliers: 12
#
# Fireplaces
# count    1460.000000
# mean        0.613014
# std         0.644666
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: Fireplaces, dtype: float64
# Mean:  0.61301369863
# Median:  1.0
# Skewness: 0.649565183055
# Kurtosis: -0.217237207528
# Outliers: 5
#
# GarageCars
# count    1460.000000
# mean        1.767123
# std         0.747315
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: GarageCars, dtype: float64
# Mean:  1.76712328767
# Median:  2.0
# Skewness: -0.342548929749
# Kurtosis: 0.220997763965
# Outliers: 0
#
# GarageArea
# count    1460.000000
# mean      472.980137
# std       213.804841
# min         0.000000
# 25%       334.500000
# 50%       480.000000
# 75%       576.000000
# max      1418.000000
# Name: GarageArea, dtype: float64
# Mean:  472.980136986
# Median:  480.0
# Skewness: 0.179980906746
# Kurtosis: 0.917067202271
# Outliers: 7
#
# WoodDeckSF
# count    1460.000000
# mean       94.244521
# std       125.338794
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       168.000000
# max       857.000000
# Name: WoodDeckSF, dtype: float64
# Mean:  94.2445205479
# Median:  0.0
# Skewness: 1.54137575719
# Kurtosis: 2.9929509247
# Outliers: 22
#
# OpenPorchSF
# count    1460.000000
# mean       46.660274
# std        66.256028
# min         0.000000
# 25%         0.000000
# 50%        25.000000
# 75%        68.000000
# max       547.000000
# Name: OpenPorchSF, dtype: float64
# Mean:  46.6602739726
# Median:  25.0
# Skewness: 2.36434174037
# Kurtosis: 8.49033580591
# Outliers: 27
#
# EnclosedPorch
# count    1460.000000
# mean       21.954110
# std        61.119149
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       552.000000
# Name: EnclosedPorch, dtype: float64
# Mean:  21.954109589
# Median:  0.0
# Skewness: 3.08987190371
# Kurtosis: 10.430765944
# Outliers: 51
#
# 3SsnPorch
# count    1460.000000
# mean        3.409589
# std        29.317331
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       508.000000
# Name: 3SsnPorch, dtype: float64
# Mean:  3.4095890411
# Median:  0.0
# Skewness: 10.3043420327
# Kurtosis: 123.66237945
# Outliers: 23
#
# ScreenPorch
# count    1460.000000
# mean       15.060959
# std        55.757415
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       480.000000
# Name: ScreenPorch, dtype: float64
# Mean:  15.0609589041
# Median:  0.0
# Skewness: 4.12221374314
# Kurtosis: 18.4390678449
# Outliers: 55
#
# PoolArea
# count    1460.000000
# mean        2.758904
# std        40.177307
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       738.000000
# Name: PoolArea, dtype: float64
# Mean:  2.75890410959
# Median:  0.0
# Skewness: 14.8283736408
# Kurtosis: 223.268498918
# Outliers: 7
#
# SalePrice
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# Mean:  180921.19589
# Median:  163000.0
# Skewness: 1.88287575977
# Kurtosis: 6.53628186006
# Outliers: 22
